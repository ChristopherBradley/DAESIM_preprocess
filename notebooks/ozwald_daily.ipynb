# %%
# Install the library into this environment if you haven't already
# !pip install daesim-preprocess

# %%
from DAESIM_preprocess.ozwald_daily import ozwald_daily, ozwald_daily_abbreviations

# %% [markdown]
# # Basic Example

# %%
# Example variables
variables = ['Tmin', 'Tmax']

lat = -34.3890427
lon=148.469499
buffer = 0.01  # Degrees in each direction (so ~2kmx2km)

start_year = 2020
end_year = 2021

# %%
# The main function
ds = ozwald_daily(variables, lat, lon, buffer, start_year, end_year)
# Out:
# Starting ozwald_daily
# Downloaded ./TEST_Tmin_2020.nc
# Downloaded ./TEST_Tmin_2021.nc
# Downloaded ./TEST_Tmax_2020.nc
# Downloaded ./TEST_Tmax_2021.nc
# Saved: ./TEST_ozwald_daily_Tmin.nc
# Saved: ./TEST_ozwald_daily_Tmin.png

# %%
# Example xarray that gets returned
ds
# Out:
# <xarray.Dataset> Size: 298kB
# Dimensions:    (time: 731, latitude: 5, longitude: 5)
# Coordinates:
#   * latitude   (latitude) float32 20B -34.38 -34.38 -34.39 -34.39 -34.4
#   * time       (time) datetime64[ns] 6kB 2020-01-01 2020-01-02 ... 2021-12-31
#   * longitude  (longitude) float32 20B 148.5 148.5 148.5 148.5 148.5
# Data variables:
#     Tmin       (time, latitude, longitude) float64 146kB 14.91 14.95 ... 13.8
#     Tmax       (time, latitude, longitude) float64 146kB 33.24 33.27 ... 29.65
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     description:         This product was derived from ERA5 reanalysis, where...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.40000086711564
#     geospatial_lat_max:  -34.375000865797126
#     geospatial_lon_min:  148.45499820302732
#     geospatial_lon_max:  148.47999820012055

# %% [markdown]
# # More examples

# %%
# Retrieving a single variable
print(f"Options: {list(ozwald_daily_abbreviations.keys())}\n")
ds = ozwald_daily(variables=['Pg'], lat=lat, lon=lon, buffer=buffer, start_year=start_year, end_year=end_year)
ds
# Out:
# Options: ['Pg', 'Tmax', 'Tmin', 'Uavg', 'Ueff', 'VPeff', 'kTavg', 'kTeff']
#
# Starting ozwald_daily
# Downloaded ./TEST_Pg_2020.nc
# Downloaded ./TEST_Pg_2021.nc
# Saved: ./TEST_ozwald_daily_Pg.nc
# Saved: ./TEST_ozwald_daily_Pg.png
# <xarray.Dataset> Size: 9kB
# Dimensions:    (time: 731, latitude: 1, longitude: 1)
# Coordinates:
#   * latitude   (latitude) float32 4B -34.38
#   * time       (time) datetime64[ns] 6kB 2020-01-01 2020-01-02 ... 2021-12-31
#   * longitude  (longitude) float32 4B 148.5
# Data variables:
#     Pg         (time, latitude, longitude) float32 3kB 0.01402 0.0 ... 0.0 0.0
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     ANU_license:         Creative Commons with Attribution (https://creativec...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.400000985930944
#     geospatial_lat_max:  -34.35000098312602
#     geospatial_lon_min:  148.45000509988694
#     geospatial_lon_max:  148.50000510896956

# %%
# Retrieving a single point
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=0, start_year=start_year, end_year=end_year)
ds
# Out:
# Starting ozwald_daily
# Downloaded ./TEST_Tmin_2020.nc
# Downloaded ./TEST_Tmin_2021.nc
# Downloaded ./TEST_Tmax_2020.nc
# Downloaded ./TEST_Tmax_2021.nc
# Saved: ./TEST_ozwald_daily_Tmin.nc
# Saved: ./TEST_ozwald_daily_Tmin.png
# <xarray.Dataset> Size: 18kB
# Dimensions:    (time: 731, latitude: 1, longitude: 1)
# Coordinates:
#   * latitude   (latitude) float32 4B -34.39
#   * time       (time) datetime64[ns] 6kB 2020-01-01 2020-01-02 ... 2021-12-31
#   * longitude  (longitude) float32 4B 148.5
# Data variables:
#     Tmin       (time, latitude, longitude) float64 6kB 14.96 18.91 ... 14.18
#     Tmax       (time, latitude, longitude) float64 6kB 33.29 34.05 ... 29.85
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     description:         This product was derived from ERA5 reanalysis, where...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.390000866588245
#     geospatial_lat_max:  -34.38500086632454
#     geospatial_lon_min:  148.4649982018646
#     geospatial_lon_max:  148.46999820128326

# %%
# Retrieving a single year
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=buffer, start_year=2020, end_year=2020)
ds
# Out:
# Starting ozwald_daily
# Downloaded ./TEST_Tmin_2020.nc
# Downloaded ./TEST_Tmax_2020.nc
# Saved: ./TEST_ozwald_daily_Tmin.nc
# Saved: ./TEST_ozwald_daily_Tmin.png
# <xarray.Dataset> Size: 149kB
# Dimensions:    (time: 366, latitude: 5, longitude: 5)
# Coordinates:
#   * latitude   (latitude) float32 20B -34.38 -34.38 -34.39 -34.39 -34.4
#   * time       (time) datetime64[ns] 3kB 2020-01-01 2020-01-02 ... 2020-12-31
#   * longitude  (longitude) float32 20B 148.5 148.5 148.5 148.5 148.5
# Data variables:
#     Tmin       (time, latitude, longitude) float64 73kB 14.91 14.95 ... 15.01
#     Tmax       (time, latitude, longitude) float64 73kB 33.24 33.27 ... 26.95
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     description:         This product was derived from ERA5 reanalysis, where...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.40000086711564
#     geospatial_lat_max:  -34.375000865797126
#     geospatial_lon_min:  148.45499820302732
#     geospatial_lon_max:  148.47999820012055

# %%
# Giving the files a new name
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=buffer, start_year=start_year, end_year=end_year,
                 stub="NEW_STUB")
# Out:
# Starting ozwald_daily
# Downloaded ./NEW_STUB_Tmin_2020.nc
# Downloaded ./NEW_STUB_Tmin_2021.nc
# Downloaded ./NEW_STUB_Tmax_2020.nc
# Downloaded ./NEW_STUB_Tmax_2021.nc
# Saved: ./NEW_STUB_ozwald_daily_Tmin.nc
# Saved: ./NEW_STUB_ozwald_daily_Tmin.png

# %%
# Saving the results in a new location
import os
if not os.path.exists('tmpdir'):
    os.mkdir('tmpdir')
if not os.path.exists('outdir'):
    os.mkdir('outdir')
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=buffer, start_year=start_year, end_year=end_year, outdir='outdir', tmpdir='tmpdir')
# Out:
# Starting ozwald_daily
# Downloaded tmpdir/TEST_Tmin_2020.nc
# Downloaded tmpdir/TEST_Tmin_2021.nc
# Downloaded tmpdir/TEST_Tmax_2020.nc
# Downloaded tmpdir/TEST_Tmax_2021.nc
# Saved: outdir/TEST_ozwald_daily_Tmin.nc
# Saved: outdir/TEST_ozwald_daily_Tmin.png

# %%
# Skipping the plot
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=buffer, start_year=start_year, end_year=end_year, 
                  plot=False)
ds
# Out:
# Starting ozwald_daily
# Downloaded ./TEST_Tmin_2020.nc
# Downloaded ./TEST_Tmin_2021.nc
# Downloaded ./TEST_Tmax_2020.nc
# Downloaded ./TEST_Tmax_2021.nc
# Saved: ./TEST_ozwald_daily_Tmin.nc
# <xarray.Dataset> Size: 298kB
# Dimensions:    (time: 731, latitude: 5, longitude: 5)
# Coordinates:
#   * latitude   (latitude) float32 20B -34.38 -34.38 -34.39 -34.39 -34.4
#   * time       (time) datetime64[ns] 6kB 2020-01-01 2020-01-02 ... 2021-12-31
#   * longitude  (longitude) float32 20B 148.5 148.5 148.5 148.5 148.5
# Data variables:
#     Tmin       (time, latitude, longitude) float64 146kB 14.91 14.95 ... 13.8
#     Tmax       (time, latitude, longitude) float64 146kB 33.24 33.27 ... 29.65
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     description:         This product was derived from ERA5 reanalysis, where...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.40000086711564
#     geospatial_lat_max:  -34.375000865797126
#     geospatial_lon_min:  148.45499820302732
#     geospatial_lon_max:  148.47999820012055

# %%
# Skipping the write to file of the final .nc 
# This is for performance to avoid write/reading if you use this object in the next step
# Note that the function still has to download a few smaller files because these get aggregated into the final xarray
ds = ozwald_daily(variables=variables, lat=lat, lon=lon, buffer=buffer, start_year=start_year, end_year=end_year, 
                  save_netcdf=False, plot=False)
ds
# Out:
# Starting ozwald_daily
# Downloaded ./TEST_Tmin_2020.nc
# Downloaded ./TEST_Tmin_2021.nc
# Downloaded ./TEST_Tmax_2020.nc
# Downloaded ./TEST_Tmax_2021.nc
# <xarray.Dataset> Size: 298kB
# Dimensions:    (time: 731, latitude: 5, longitude: 5)
# Coordinates:
#   * latitude   (latitude) float32 20B -34.38 -34.38 -34.39 -34.39 -34.4
#   * time       (time) datetime64[ns] 6kB 2020-01-01 2020-01-02 ... 2021-12-31
#   * longitude  (longitude) float32 20B 148.5 148.5 148.5 148.5 148.5
# Data variables:
#     Tmin       (time, latitude, longitude) float64 146kB 14.91 14.95 ... 13.8
#     Tmax       (time, latitude, longitude) float64 146kB 33.24 33.27 ... 29.65
# Attributes:
#     creator_name:        ANU Centre for Water and Landscape Dynamics
#     creator_url:         http://wald.anu.edu.au
#     creator_email:       albert.vandijk@anu.edu.au
#     institution:         Australian National University
#     date_created:        25-Feb-2021
#     description:         This product was derived from ERA5 reanalysis, where...
#     Conventions:         CF-1.0
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -34.40000086711564
#     geospatial_lat_max:  -34.375000865797126
#     geospatial_lon_min:  148.45499820302732
#     geospatial_lon_max:  148.47999820012055

# %% [markdown]
# # Useful resources
# - Source code: https://github.com/ChristopherBradley/DAESIM_preprocess/blob/main/src/DAESIM_preprocess/ozwald_daily.py
# - OzWald catalog: https://thredds.nci.org.au/thredds/catalog/ub8/au/OzWALD/daily/meteo/catalog.html
# - TERN data visualiser: https://maps.tern.org.au/map
# - The other TERN data visualiser: https://ausenv.tern.org.au/aex/index.html
#
# # References
# - Van Dijk, AIJM (2010) The Australian Water Resources Assessment System. Technical
# Report 3. Landscape Model (version 0.5) Technical Description, CSIRO: Water for a Healthy Country National Research Flagship, https://awo.bom.gov.au/assets/notes/publications/Van_Dijk_AWRA05_TechReport3.pdf
# - Van Dijk AIJM, Rahman J (2019) Synthesising multiple observations into annual environmental condition reports: the OzWALD system and Australia’s Environment Explorer. In Elsawah, S. (ed.) MODSIM2019, 23rd International Congress on Modelling and Simulation. Modelling and Simulation Society of Australia and New Zealand, pp. 884–890. ISBN: 978-0-9758400-9-2, https://doi.org/10.36334/modsim.2019.J5.vandijk
